# %% [markdown]
# # Byte-Pair Encoding (BPE) Tokenizer

# %% [markdown]
# ## The Unicode Standard

# %% [markdown]
# ## Problem (unicode1): Understanding Unicode (1 point)

# %% [markdown]
# a) What Unicode character does chr(0) return?
#
# The `chr(0)` function returns the Unicode character with code point 0, which is the **null character** (often represented as `'\0'`). It is a control character used to signify the end of a string in many programming languages and systems. In Unicode, it is referred to as "NULL" and has no visual representation.

# %%
string = chr(0)

string
# Out:
# '\x00'

# %% [markdown]
# b) How does this character’s string representation (__repr__()) differ from its printed representation?
#
# The string representation of a character using __repr__() provides a detailed and unambiguous representation of the object, often including escape sequences for non-printable characters. For the null character (chr(0)), __repr__() would return '\x00', showing its hexadecimal escape code.
#
# In contrast, the printed representation (print()) attempts to display the character as-is. Since the null character has no visual representation, printing it results in no visible output.

# %%
string.__repr__()
# Out:
# "'\\x00'"

# %% [markdown]
# c) What happens when this character occurs in text?
#
# When using print function with a string containing the null character, it will not display anything for that character.

# %%
"this is a test" + chr(0) + "string"
# Out:
# 'this is a test\x00string'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %% [markdown]
# ## Problem (unicode2): Unicode Encodings (3 points)

# %% [markdown]
# a) What are some reasons to prefer training our tokenizer on UTF-8 encoded bytes, rather than UTF-16 or UTF-32? It may be helpful to compare the output of these encodings for various input strings
#
# UTF-8 is often preferred for training tokenizers for several reasons:
#
# 1. **Space Efficiency**: UTF-8 uses a variable-length encoding scheme, where common characters (like ASCII) are represented with one byte, while less common characters use more bytes. This makes it more space-efficient for texts that primarily consist of ASCII characters.
#
# 2. **Compatibility**: UTF-8 is backward compatible with ASCII, meaning that any valid ASCII text is also valid UTF-8 text. This compatibility makes it easier to work with existing systems and libraries that expect ASCII input.
#
# 3. **Widespread Adoption**: UTF-8 is the most widely used encoding on the web and in many programming languages, making it easier to find libraries and tools that support it.
#
# 4. **Simplicity**: UTF-8's variable-length encoding allows for efficient processing of text, as it can handle a wide range of characters without requiring additional complexity in handling fixed-width encodings like UTF-16 or UTF-32.
#
# 5. **Avoiding BOM**: UTF-16 and UTF-32 often include a Byte Order Mark (BOM) to indicate endianness, which can complicate text processing. UTF-8 does not require a BOM, simplifying the handling of text files.

# %% [markdown]
# b) Consider the following (incorrect) function, which is intended to decode a UTF-8 byte string into a Unicode string. Why is this function incorrect? Provide an example of an input byte string that yields incorrect results.

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])

# %%
decode_utf8_bytes_to_str_wrong("hello".encode("utf-8"))
# Out:
# 'hello'

# %% [markdown]
# The function decode_utf8_bytes_to_str_wrong is incorrect because it attempts to decode each byte in the input byte string individually, rather than decoding the entire byte string as a single UTF-8 encoded sequence. UTF-8 is a variable-length encoding, meaning that some characters are represented by multiple bytes. Decoding each byte separately will fail for multi-byte characters, as the individual bytes do not represent valid UTF-8 characters on their own.

# %%
eur_sign = b'\xe2\x82\xac'

print(eur_sign.decode("utf-8"))
# Out:
# €

# %%
try:
    decode_utf8_bytes_to_str_wrong(eur_sign)
except UnicodeDecodeError as e:
    print(f"UnicodeDecodeError: {e}")
# Out:
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 0: unexpected end of data

# %% [markdown]
# When using this function, it will raise a `UnicodeDecodeError` when it encounters a byte sequence that does not correspond to a valid UTF-8 character.

# %% [markdown]
# ## BPE Tokenizer Training

# %%
from cs336_basics.bpe.utils import find_chunk_boundaries

# %%
# Get number of CPU cores
import multiprocessing
num_cores = multiprocessing.cpu_count()
print(f"Number of CPU cores: {num_cores}")
# Out:
# Number of CPU cores: 8

# %%
with open('./data/owt_train.txt', "rb") as f:
    boundaries = find_chunk_boundaries(
        f, num_cores, "<|endoftext|>".encode("utf-8")
    )

print(f"Chunk boundaries: {boundaries}")
# Out:
# Chunk boundaries: [0, 1490070394, 2980128270, 4470223005, 5960269363, 7450321387, 8940385101, 10430448049, 11920511059]

# %%
with open('./data/owt_train.txt', "rb") as f:
    start, end = boundaries[0], boundaries[1]
    f.seek(start)
    chunk = f.read(end - start)
print(f"Chunk size: {len(chunk)} bytes")
# Out:
# Chunk size: 1490070394 bytes

# %%
chunk_str = chunk.decode("utf-8", errors="ignore")

print(f"Chunk string length: {len(chunk_str)} characters, first 100 characters: {chunk_str[:100]}")
# Out:
# Chunk string length: 1476958212 characters, first 100 characters: What wouldn't you do to save someone you love?
#
# When They Come Calling is a modern ghost story, a su

# %%
from pathlib import Path

with open(Path('.').parent / "tests/fixtures/corpus.en",) as f:
    chunk_str = f.read()

chunk_str
# Out:
# 'iron cement is a ready for use paste which is laid as a fillet by putty knife or finger in the mould edges ( corners ) of the steel ingot mould .\niron cement protects the ingot against the hot , abrasive steel casting process .\na fire restant repair cement for fire places , ovens , open fireplaces etc .\nconstruction and repair of highways and ...\nan announcement must be commercial character .\ngoods and services advancement through the P.O.Box system is NOT ALLOWED .\ndeliveries ( spam ) and other improper information deleted .\ntranslator Internet is a Toolbar for MS Internet Explorer .\nit allows you to translate in real time any web pasge from one language to another .\nyou only have to select languages and TI does all the work for you ! automatic dictionary updates ....\nthis software is written in order to increase your English keyboard typing speed , through teaching the basics of how to put your hand on to the keyboard and give some training examples .\neach lesson teaches some extra keys , and there is also a practice , if it is chosen , one can practice the previous keys learned through the previous lessons . the words chosen in the practice are mostly meaningful and relates to the tough keys ...\nare you one of millions out there who are trying to learn foreign language , but never have enough time ?\nget VTeacher , a screensaver that displays words and phrases you are trying to learn and their translation .\nlaunch it during your office break and add new words to your vocabulary while sipping hot coffee and chewing a sandwich .\nthis is a one time charge and you will never be rebilled !\nyou will receive direct access to a registration code automatically after you place your order . the entire process of registration and cleaning your system should take less than 5 minutes .\nyou will also receive a confirmation email with your order information ( registration code , order # , etc ) ...\nthe English @-@ German Pro Dictionary contains over 50,813 words and 23,343 articles presented in rich @-@ text format articles .\nthe dictionary is a wonderful bilingual reference tool and can be used both by beginners and advanced learners ...\nthe MSDict English @-@ Spanish Pro Dictionary contains over 38,000 entries in 19,800 word articles , presented in rich @-@ text format .\nthe dictionary is a wonderful bilingual reference tool and can be used both by beginners and advanced learners of English and Spanish ...\npocket Oxford English Dictionary First Published in 1924 This is a reissue of the ninth edition of the world &apos;s longest @-@ established pocket English dictionary by Oxford University Press .\nit is one of the new generation Oxford dictionaries derived from the database of the highly acclaimed New Oxford Dictionary of English and is particularly user friendly with its elegant open design , with different elements starting on new lines ...\nWordBanker is a unique and fun method of helping you to learn a foreign language .\nrather than bog you down with complicated grammar it deals only with building a vocabulary .\ntrouble memorising new words or phrases ?\nWordBanker &apos;s &quot; Visual Clue &quot; method of testing means you learn without even realising it .\ncan be used by French people learning English or English people learning English ...\nthe English Pro Dictionary for Series 60 Smartphones is an extensive dictionary and thesaurus with over 90,000 words , geared to the needs of a wide range of users- from the student at intermediate level and above to the enthusiastic tourist , or native English speaking business professional ...\nWordBanker is a unique and fun method of helping you to learn a foreign language . rather than bog you down with complicated grammar it deals only with building a vocabulary .\ntrouble memorising new words or phrases ? WordBanker &apos;s &quot; Visual Clue &quot; method of testing means you learn without even realising it .\ncan be used by Italian people learning English or E ...

# %%
from cs336_basics.bpe.normalization import normalize_text

# %%
normalized_chunk = normalize_text(chunk_str)
normalized_chunk
# Out:
# 'iron cement is a ready for use paste which is laid as a fillet by putty knife or finger in the mould edges ( corners ) of the steel ingot mould . iron cement protects the ingot against the hot , abrasive steel casting process . a fire restant repair cement for fire places , ovens , open fireplaces etc . construction and repair of highways and ... an announcement must be commercial character . goods and services advancement through the P.O.Box system is NOT ALLOWED . deliveries ( spam ) and other improper information deleted . translator Internet is a Toolbar for MS Internet Explorer . it allows you to translate in real time any web pasge from one language to another . you only have to select languages and TI does all the work for you ! automatic dictionary updates .... this software is written in order to increase your English keyboard typing speed , through teaching the basics of how to put your hand on to the keyboard and give some training examples . each lesson teaches some extra keys , and there is also a practice , if it is chosen , one can practice the previous keys learned through the previous lessons . the words chosen in the practice are mostly meaningful and relates to the tough keys ... are you one of millions out there who are trying to learn foreign language , but never have enough time ? get VTeacher , a screensaver that displays words and phrases you are trying to learn and their translation . launch it during your office break and add new words to your vocabulary while sipping hot coffee and chewing a sandwich . this is a one time charge and you will never be rebilled ! you will receive direct access to a registration code automatically after you place your order . the entire process of registration and cleaning your system should take less than 5 minutes . you will also receive a confirmation email with your order information ( registration code , order # , etc ) ... the English @-@ German Pro Dictionary contains over 50,813 words and 23,343 articles presented in rich @-@ text format articles . the dictionary is a wonderful bilingual reference tool and can be used both by beginners and advanced learners ... the MSDict English @-@ Spanish Pro Dictionary contains over 38,000 entries in 19,800 word articles , presented in rich @-@ text format . the dictionary is a wonderful bilingual reference tool and can be used both by beginners and advanced learners of English and Spanish ... pocket Oxford English Dictionary First Published in 1924 This is a reissue of the ninth edition of the world &apos;s longest @-@ established pocket English dictionary by Oxford University Press . it is one of the new generation Oxford dictionaries derived from the database of the highly acclaimed New Oxford Dictionary of English and is particularly user friendly with its elegant open design , with different elements starting on new lines ... WordBanker is a unique and fun method of helping you to learn a foreign language . rather than bog you down with complicated grammar it deals only with building a vocabulary . trouble memorising new words or phrases ? WordBanker &apos;s &quot; Visual Clue &quot; method of testing means you learn without even realising it . can be used by French people learning English or English people learning English ... the English Pro Dictionary for Series 60 Smartphones is an extensive dictionary and thesaurus with over 90,000 words , geared to the needs of a wide range of users- from the student at intermediate level and above to the enthusiastic tourist , or native English speaking business professional ... WordBanker is a unique and fun method of helping you to learn a foreign language . rather than bog you down with complicated grammar it deals only with building a vocabulary . trouble memorising new words or phrases ? WordBanker &apos;s &quot; Visual Clue &quot; method of testing means you learn without even realising it . can be used by Italian people learning English or English people learning Italian . ...

# %%
from cs336_basics.bpe.tokenization import count_word_frequencies, get_alphabet

word_counts = count_word_frequencies(normalized_chunk)

print(f"Number of unique subwords: {len(word_counts)}")
print(f"Most common subwords: {sorted(word_counts.items(), key=lambda x: x[1], reverse=True)[:10]}")
# Out:
# Number of unique subwords: 4475
# Most common subwords: [(b'the', 1357), (b',', 1326), (b'.', 1039), (b'of', 646), (b'and', 629), (b'a', 490), (b'to', 483), (b';', 480), (b'in', 456), (b'is', 339)]

# %%
list(word_counts.keys())
# Out:
# [b'iron',
#  b'cement',
#  b'is',
#  b'a',
#  b'ready',
#  b'for',
#  b'use',
#  b'paste',
#  b'which',
#  b'laid',
#  b'as',
#  b'fillet',
#  b'by',
#  b'putty',
#  b'knife',
#  b'or',
#  b'finger',
#  b'in',
#  b'the',
#  b'mould',
#  b'edges',
#  b'(',
#  b'corners',
#  b')',
#  b'of',
#  b'steel',
#  b'ingot',
#  b'.',
#  b'protects',
#  b'against',
#  b'hot',
#  b',',
#  b'abrasive',
#  b'casting',
#  b'process',
#  b'fire',
#  b'restant',
#  b'repair',
#  b'places',
#  b'ovens',
#  b'open',
#  b'fireplaces',
#  b'etc',
#  b'construction',
#  b'and',
#  b'highways',
#  b'...',
#  b'an',
#  b'announcement',
#  b'must',
#  b'be',
#  b'commercial',
#  b'character',
#  b'goods',
#  b'services',
#  b'advancement',
#  b'through',
#  b'P',
#  b'O',
#  b'Box',
#  b'system',
#  b'NOT',
#  b'ALLOWED',
#  b'deliveries',
#  b'spam',
#  b'other',
#  b'improper',
#  b'information',
#  b'deleted',
#  b'translator',
#  b'Internet',
#  b'Toolbar',
#  b'MS',
#  b'Explorer',
#  b'it',
#  b'allows',
#  b'you',
#  b'to',
#  b'translate',
#  b'real',
#  b'time',
#  b'any',
#  b'web',
#  b'pasge',
#  b'from',
#  b'one',
#  b'language',
#  b'another',
#  b'only',
#  b'have',
#  b'select',
#  b'languages',
#  b'TI',
#  b'does',
#  b'all',
#  b'work',
#  b'!',
#  b'automatic',
#  b'dictionary',
#  b'updates',
#  b'....',
#  b'this',
#  b'software',
#  b'written',
#  b'order',
#  b'increase',
#  b'your',
#  b'English',
#  b'keyboard',
#  b'typing',
#  b'speed',
#  b'teaching',
#  b'basics',
#  b'how',
#  b'put',
#  b'hand',
#  b'on',
#  b'give',
#  b'some',
#  b'training',
#  b'examples',
#  b'each',
#  b'lesson',
#  b'teaches',
#  b'extra',
#  b'keys',
#  b'there',
#  b'also',
#  b'practice',
#  b'if',
#  b'chosen',
#  b'can',
#  b'previous',
#  b'learned',
#  b'lessons',
#  b'words',
#  b'are',
#  b'mostly',
#  b'meaningful',
#  b'relates',
#  b'tough',
#  b'millions',
#  b'out',
#  b'who',
#  b'trying',
#  b'learn',
#  b'foreign',
#  b'but',
#  b'never',
#  b'enough',
#  b'?',
#  b'get',
#  b'VTeacher',
#  b'screensaver',
#  b'that',
#  b'displays',
#  b'phrases',
#  b'their',
#  b'translation',
#  b'launch',
#  b'during',
#  b'office',
#  b'break',
#  b'add',
#  b'new',
#  b'vocabulary',
#  b'while',
#  b'sipping',
#  b'coffee',
#  b'chewing',
#  b'sandwich',
#  b'charge',
#  b'will',
#  b'rebilled',
#  b'receive',
#  b'direct',
#  b'access',
#  b'registration',
#  b'code',
#  b'automatically',
#  b'after',
#  b'place',
#  b'entire',
#  b'cleaning',
#  b'should',
#  b'take',
#  b'less',
#  b'than',
#  b'5',
#  b'minutes',
#  b'confirmation',
#  b'email',
#  b'with',
#  b'#',
#  b'@-@',
#  b'German',
#  b'Pro',
#  b'Dictionary',
#  b'contains',
#  b'over',
#  b'50',
#  b'813',
#  b'23',
#  b'343',
#  b'articles',
#  b'presented',
#  b'rich',
#  b'text',
#  b'format',
#  b'wonderful',
#  b'bilingual',
#  b'reference',
#  b'tool',
#  b'used',
#  b'both',
#  b'beginners',
#  b'advanced',
#  b'learners',
#  b'MSDict',
#  b'Spanish',
#  b'38',
#  b'000',
#  b'entries',
#  b'19',
#  b'800',
#  b'word',
#  b'pocket',
#  b'Oxford',
#  b'First',
#  b'Published',
#  b'1924',
#  b'This',
#  b'reissue',
#  b'ninth',
#  b'edition',
#  b'world',
#  b'&',
#  b'apos',
#  b';',
#  b's',
#  b'longest',
#  b'established',
#  b'University',
#  b'Press',
#  b'generation',
#  b'dictionaries',
#  b'derived',
#  b'database',
#  b'highly',
#  b'acclaimed',
#  b'New',
#  b'particularly',
#  b'user',
#  b'friendly',
#  b'its',
#  b'elegant',
#  b'design',
#  b'different',
#  b'elements',
#  b'starting',
#  b'lines',
#  b'WordBanker',
#  b'unique',
#  b'fun',
#  b'method',
#  b'helping',
#  b'rather',
#  b'bog',
#  b'down',
#  b'complicated',
#  b'grammar',
#  b'deals',
#  b'building',
#  b'trouble',
#  b'memorising',
#  b'quot',
#  b'Visual',
#  b'Clue',
#  b'testing',
#  b'means',
#  b'without',
#  b'even',
#  b'realising',
#  b'French',
#  b'people',
#  b'learning',
#  b'Series',
#  b'60',
#  b'Smartphones',
#  b'extensive',
#  b'thesaurus',
#  b'90',
#  b'geared',
#  b'needs',
#  b'wide',
#  b'range',
#  b'users',
#  b'-',
#  b'student',
#  b'at',
#  b'intermediate',
#  b'level',
#  b'above',
#  b'enthusiastic',
#  b'tourist',
#  b'native',
#  b'speaking',
#  b'business',
#  b'professional',
#  b'Italian',
#  b'line',
#  b'LingvoSoft',
#  b'Albanian',
#  b'Dictionaries',
#  b'Windows',
#  b'brings',
#  b'accurate',
#  b'prompt',
#  b'two',
#  b'way',
#  b'translations',
#  b'wrapped',
#  b'interface',
#  b'convenient',
#  b'search',
#  b'options',
#  b'they',
#  b'built',
#  b'updated',
#  b'linguistic',
#  b'databases',
#  b'come',
#  b'four',
#  b'versions',
#  b'designed',
#  b'types',
#  b'Basic',
#  b'compact',
#  b'fast',
#  b'easy',
#  b'screen',
#  b'saver',
#  b'beautiful',
#  b'paintings',
#  b'quaint',
#  b'cottages',
#  b'makes',
#  b'gift',
#  b'family',
#  b'member',
#  b'friend',
#  b'features',
#  b'very',
#  b'stable',
#  b'engine',
#  b'several',
#  b'definable',
#  b'attractive',
#  b'intuitive',
#  b'95',
#  b'/',
#  b'98',
#  b'NT',
#  b'Desktop',
#  b'Properties',
#  b'dialog',
#  b'live',
#  b'preview',
#  b'Pocket',
#  b'Viewer',
#  b'treasures',
#  b'PC',
#  b'Phrases',
#  b'includes',
#  b'variety',
#  b'collocations',
#  b'common',
#  b'idioms',
#  b'provides',
#  b'11',
#  b'107',
#  b'definitions',
#  b'9',
#  b'works',
#  b'file',
#  b'fully',
#  b'compatible',
#  b'useful',
#  b'functionalities',
#  b'viewer',
#  b'among',
#  b'most',
#  b'commonly',
#  b'American',
#  b'British',
#  b'featuring',
#  b'65',
#  b'efficient',
#  b'application',
#  b'provide',
#  b'study',
#  b'material',
#  b'immediate',
#  b'practical',
#  b'help',
#  b'when',
#  b'faced',
#  b'communication',
#  b'challenge',
#  b'requiring',
#  b'instant',
#  b'response',
#  b'potential',
#  b'productivity',
#  b'gains',
#  b'considerable',
#  b'today',
#  b'QuarkXPress',
#  b'\xc2\xae',
#  b'8',
#  b'has',
#  b'tighter',
#  b'integration',
#  b'Photoshop',
#  b'Illustrator',
#  b'ever',
#  b'before',
#  b'standards',
#  b'like',
#  b'HTML',
#  b'CSS',
#  b'publish',
#  b'across',
#  b'media',
#  b'independently',
#  b'alongside',
#  b'Adobe',
#  b'Creative',
#  b'Suite',
#  b'applications',
#  b'Flash',
#  b'SWF',
#  b'Dreamweaver',
#  b'here',
#  b'll',
#  b'find',
#  b'best',
#  b'possible',
#  b'interaction',
#  b'surprised',
#  b'Quark',
#  b'made',
#  b'unlock',
#  b'full',
#  b'considered',
#  b'many',
#  b'PSD',
#  b'layout',
#  b'available',
#  b'section',
#  b'we',
#  b'explain',
#  b'images',
#  b'them',
#  b'example',
#  b'may',
#  b'multiple',
#  b'layers',
#  b'product',
#  b'shots',
#  b'vary',
#  b'publication',
#  b'switch',
#  b'those',
#  b'off',
#  b'having',
#  b'save',
#  b'separate',
#  b'TIFF',
#  b'question',
#  b'might',
#  b'tip',
#  b'favor',
#  b'Do',
#  b'I',
#  b'need',
#  b'spot',
#  b'color',
#  b'image',
#  b'using',
#  b'colors',
#  b'formats',
#  b'often',
#  b'however',
#  b'because',
#  b'supports',
#  b'channels',
#  b'simpler',
#  b'more',
#  b'flexible',
#  b'bringing',
#  b'files',
#  b'into',
#  b'same',
#  b'create',
#  b'then',
#  b'File',
#  b'gt',
#  b'Import',
#  b'simply',
#  b'drag',
#  b'drop',
#  b'desktop',
#  b'Finder',
#  b'Bridge',
#  b'creating',
#  b'box',
#  b'first',
#  b'special',
#  b'palette',
#  b'window',
#  b'You',
#  b'instantly',
#  b'see',
#  b'thumbnails',
#  b'along',
#  b'names',
#  b've',
#  b'created',
#  b'layer',
#  b'antiqued',
#  b'look',
#  b'seems',
#  b'swamped',
#  b'surrounding',
#  b'option',
#  b'reduce',
#  b'opacity',
#  b'clicking',
#  b'entering',
#  b'want',
#  b'ink',
#  b'plate',
#  b'set',
#  b'up',
#  b'channel',
#  b'do',
#  b'maybe',
#  b'intend',
#  b'varnish',
#  b'part',
#  b'within',
#  b're',
#  b'\xc2\xad',
#  b'map',
#  b'right',
#  b'non',
#  b'destructively',
#  b'so',
#  b'click',
#  b'divider',
#  b'Palette',
#  b'double',
#  b'pick',
#  b'project',
#  b'ensuring',
#  b'consistency',
#  b'powerful',
#  b'support',
#  b't',
#  b'manipulate',
#  b'certain',
#  b'kinds',
#  b'such',
#  b'effects',
#  b'&#',
#  b'91',
#  b'e',
#  b'g',
#  b'these',
#  b'import',
#  b'print',
#  b'just',
#  b'fine',
#  b'won',
#  b'controls',
#  b'functionality',
#  b'eliminate',
#  b'converting',
#  b'stand',
#  b'alone',
#  b'smart',
#  b'objects',
#  b'Layer',
#  b'93',
#  b'adjustment',
#  b'3',
#  b'D',
#  b'including',
#  b'blending',
#  b'mode',
#  b'great',
#  b'logos',
#  b'vector',
#  b'illustrations',
#  b'traditionally',
#  b'route',
#  b'been',
#  b'export',
#  b'EPS',
#  b'now',
#  b'things',
#  b'much',
#  b'easier',
#  b'arrival',
#  b'ai',
#  b'would',
#  b'graphics',
#  b'transparency',
#  b'doesn',
#  b'partially',
#  b'transparent',
#  b'PDF',
#  b'yet',
#  b'something',
#  b'shadow',
#  b'plan',
#  b'white',
#  b'background',
#  b'object',
#  b'undesirable',
#  b'results',
#  b'good',
#  b'news',
#  b'imported',
#  b'apply',
#  b'change',
#  b'instead',
#  b'well',
#  b'equipped',
#  b'drawing',
#  b'tasks',
#  b'our',
#  b'newest',
#  b'release',
#  b'standardised',
#  b'tools',
#  b'Freehand',
#  b'similar',
#  b'watch',
#  b'video',
#  b'compelling',
#  b'page',
#  b'professionals',
#  b'projects',
#  b'compromising',
#  b'authoring',
#  b'capabilities',
#  b'included',
#  b'every',
#  b'working',
#  b'familiar',
#  b'environment',
#  b'existing',
#  b'jobs',
#  b'no',
#  b'additional',
#  b'purchase',
#  b'coding',
#  b'required',
#  b'sophisticated',
#  b'designs',
#  b'*',
#  b'InDesign',
#  b'CS',
#  b'4',
#  b':',
#  b'interactive',
#  b'hyperlinks',
#  b'transitions',
#  b'button',
#  b'actions',
#  b'not',
#  b'XFL',
#  b'disclaimer',
#  b'document',
#  b'based',
#  b'publicly',
#  b'hands',
#  b'evaluation',
#  b'content',
#  b'revised',
#  b'Inc',
#  b'accepts',
#  b'responsibility',
#  b'legal',
#  b'otherwise',
#  b'accuracy',
#  b'Web',
#  b'layouts',
#  b'menus',
#  b'convert',
#  b'fancy',
#  b'treatments',
#  b'write',
#  b'opened',
#  b'directly',
#  b'version',
#  b'1',
#  b'7',
#  b'default',
#  b'Quality',
#  b'setting',
#  b'once',
#  b'becomes',
#  b'clear',
#  b'represent',
#  b'thousands',
#  b'dollars',
#  b'return',
#  b'investment',
#  b'course',
#  b'year',
#  b'\xc2\xa9',
#  b'2009',
#  b'Media',
#  b'House',
#  b'S\xc3\xa0rl',
#  b'Switzerland',
#  b'arbitration',
#  b'form',
#  b'alternative',
#  b'dispute',
#  b'resolution',
#  b'specifically',
#  b'litigation',
#  b'whereby',
#  b'parties',
#  b'agree',
#  b'submit',
#  b'respective',
#  b'positions',
#  b'agreement',
#  b'hearing',
#  b'neutral',
#  b'third',
#  b'party',
#  b'arbitrator',
#  b'arbiter',
#  b'mediation',
#  b'mediator',
#  b'assists',
#  b'negotiate',
#  b'matter',
#  b'interest',
#  b'company',
#  b'Law',
#  b'regulates',
#  b'formations',
#  b'directors',
#  b'duties',
#  b'shareholder',
#  b'agreements',
#  b'interpretation',
#  b'relevant',
#  b'statutory',
#  b'law',
#  b'European',
#  b'Union',
#  b'Hungary',
#  b'continues',
#  b'demonstrate',
#  b'economic',
#  b'growth',
#  b'embassies',
#  b'transnational',
#  b'companies',
#  b'located',
#  b'capital',
#  b'bring',
#  b'expatriate',
#  b'foreigners',
#  b'families',
#  b'town',
#  b'demand',
#  b'private',
#  b'international',
#  b'schools',
#  b'1990',
#  b'Haidegger',
#  b'amp',
#  b'Partner',
#  b'Budapest',
#  b'providing',
#  b'offering',
#  b'individual',
#  b'tailored',
#  b'advice',
#  b'apart',
#  b'being',
#  b'principal',
#  b'political',
#  b'industrial',
#  b'transportation',
#  b'centre',
#  b'city',
#  b'boasts',
#  b'sites',
#  b'monuments',
#  b'spas',
#  b'worldwide',
#  b'renown',
#  b'statistic',
#  b'6819',
#  b'ecommerce',
#  b'eshops',
#  b'distributors',
#  b'comparison',
#  b'ASPs',
#  b'systems',
#  b'downloading',
#  b'ICEcat',
#  b'data',
#  b'sheet',
#  b'since',
#  b'Oct',
#  b'2007',
#  b'sponsoring',
#  b'brands',
#  b'free',
#  b'Open',
#  b'distribution',
#  b'6328',
#  b'Acer',
#  b'projector',
#  b'accessories',
#  b'optimize',
#  b'X',
#  b'1160',
#  b'1260',
#  b'projectors',
#  b'expand',
#  b'usage',
#  b'mobility',
#  b'07',
#  b'Sep',
#  b'2005',
#  b'6821',
#  b'08',
#  b'Jun',
#  b'2006',
#  b'6815',
#  b'14',
#  b'AKVIS',
#  b'Sketch',
#  b'converts',
#  b'digital',
#  b'photos',
#  b'amazing',
#  b'pencil',
#  b'sketches',
#  b'watercolor',
#  b'drawings',
#  b'photo',
#  b'oil',
#  b'painting',
#  b'ArtWork',
#  b'Chameleon',
#  b'collage',
#  b'creation',
#  b'Enhancer',
#  b'enhancement',
#  b'program',
#  b'revealing',
#  b'details',
#  b'picture',
#  b'detecting',
#  b'underexposed',
#  b'overexposed',
#  b'mid',
#  b'tone',
#  b'areas',
#  b'SmartMask',
#  b'masking',
#  b'saves',
#  b'complex',
#  b'selections',
#  b'Coloriage',
#  b'colorizing',
#  b'B',
#  b'W',
#  b'replacing',
#  b'Noise',
#  b'Buster',
#  b'noise',
#  b'suppression',
#  b'scanned',
#  b'ArtSuite',
#  b'impressive',
#  b'collection',
#  b'versatile',
#  b'decoration',
#  b'effect',
#  b'groups',
#  b'frames',
#  b'let',
#  b'generate',
#  b'frame',
#  b'artistic',
#  b'allow',
#  b'experimenting',
#  b'adding',
#  b'texture',
#  b'Magnifier',
#  b'resizing',
#  b'loss',
#  b'quality',
#  b'Retoucher',
#  b'Plug',
#  b'restoration',
#  b'retouching',
#  b'removes',
#  b'dust',
#  b'scratches',
#  b'stains',
#  b'defects',
#  b'appear',
#  b'damaged',
#  b'reconstructs',
#  b'lacking',
#  b'parts',
#  b'sourrounding',
#  b'0',
#  b'offers',
#  b'improves',
#  b'compatibility',
#  b'Macintosh',
#  b'standalone',
#  b'presents',
#  b'Hand',
#  b'Painted',
#  b'Frames',
#  b'artists',
#  b'person',
#  b'tattoos',
#  b'around',
#  b'chest',
#  b'area',
#  b'tried',
#  b'times',
#  b'cover',
#  b'couldn',
#  b'downloaded',
#  b'trial',
#  b'pass',
#  b'were',
#  b'gone',
#  b'was',
#  b'absolutely',
#  b'shocked',
#  b'Akvis',
#  b'know',
#  b'young',
#  b'lady',
#  b'tattoo',
#  b'too',
#  b'insight',
#  b'prompted',
#  b'launching',
#  b'1983',
#  b'Design',
#  b'Plus',
#  b'competition',
#  b'Messe',
#  b'Frankfurt',
#  b'cooperation',
#  b'Rat',
#  b'f\xc3\xbcr',
#  b'Formgebung',
#  b'Council',
#  b'Deutschen',
#  b'Industrie',
#  b'und',
#  b'Handelskammertag',
#  b'Association',
#  b'Chambers',
#  b'Industry',
#  b'Commerce',
#  b'DIHK',
#  b'award',
#  b'distinguished',
#  b'jury',
#  b'conjunction',
#  b'Ambiente',
#  b'consumer',
#  b'trade',
#  b'fair',
#  b'stands',
#  b'merely',
#  b'end',
#  ...]

# %%
from cs336_basics.bpe.tokenization import split_words

splits = split_words(word_counts)

for word in list(splits.keys()):  # Display only first 10 words
    if '(' in word.decode('utf-8'):
       print(f"Word: '{word}', Splits: {splits[word]}")
# Out:
# Word: 'b'('', Splits: [b'(']

# %%
from cs336_basics.bpe.tokenization import compute_pair_freqs

pair_freqs = compute_pair_freqs(splits, word_counts)
print(f"Number of unique pairs: {len(pair_freqs)}")
print(f"Most common pairs: {sorted(pair_freqs.items(), key=lambda x: x[1], reverse=True)[:10]}")
# Out:
# Number of unique pairs: 985
# Most common pairs: [((b't', b'h'), 2764), ((b'h', b'e'), 2168), ((b'i', b'n'), 1890), ((b'e', b'r'), 1564), ((b'r', b'e'), 1490), ((b'a', b'n'), 1488), ((b'o', b'r'), 1258), ((b'o', b'n'), 1214), ((b'n', b'd'), 1117), ((b'a', b't'), 1110)]

# %%
from cs336_basics.bpe.tokenization import merge_pair

# %%
from copy import deepcopy

clone_splits = deepcopy(splits)

pair_to_merge = max(list(pair_freqs.keys()), key=lambda k: pair_freqs[k])
print(f"Merging pair: {pair_to_merge} with frequency: {pair_freqs[pair_to_merge]}")

first_word, second_word = pair_to_merge
merge_pair(first_word, second_word, clone_splits, word_counts)

new_word = first_word + second_word
for word in list(clone_splits.keys()):
    if new_word in word:
        print(f"Word '{word}' after merging: {clone_splits[word]}")
# Out:
# Merging pair: (b't', b'h') with frequency: 2764
# Word 'b'the'' after merging: [b'th', b'e']
# Word 'b'through'' after merging: [b'th', b'r', b'o', b'u', b'g', b'h']
# Word 'b'other'' after merging: [b'o', b'th', b'e', b'r']
# Word 'b'another'' after merging: [b'a', b'n', b'o', b'th', b'e', b'r']
# Word 'b'this'' after merging: [b'th', b'i', b's']
# Word 'b'there'' after merging: [b'th', b'e', b'r', b'e']
# Word 'b'that'' after merging: [b'th', b'a', b't']
# Word 'b'their'' after merging: [b'th', b'e', b'i', b'r']
# Word 'b'than'' after merging: [b'th', b'a', b'n']
# Word 'b'with'' after merging: [b'w', b'i', b'th']
# Word 'b'both'' after merging: [b'b', b'o', b'th']
# Word 'b'ninth'' after merging: [b'n', b'i', b'n', b'th']
# Word 'b'method'' after merging: [b'm', b'e', b'th', b'o', b'd']
# Word 'b'rather'' after merging: [b'r', b'a', b'th', b'e', b'r']
# Word 'b'without'' after merging: [b'w', b'i', b'th', b'o', b'u', b't']
# Word 'b'thesaurus'' after merging: [b'th', b'e', b's', b'a', b'u', b'r', b'u', b's']
# Word 'b'enthusiastic'' after merging: [b'e', b'n', b'th', b'u', b's', b'i', b'a', b's', b't', b'i', b'c']
# Word 'b'they'' after merging: [b'th', b'e', b'y']
# Word 'b'them'' after merging: [b'th', b'e', b'm']
# Word 'b'those'' after merging: [b'th', b'o', b's', b'e']
# Word 'b'then'' after merging: [b'th', b'e', b'n']
# Word 'b'thumbnails'' after merging: [b'th', b'u', b'm', b'b', b'n', b'a', b'i', b'l', b's']
# Word 'b'within'' after merging: [b'w', b'i', b'th', b'i', b'n']
# Word 'b'these'' after merging: [b'th', b'e', b's', b'e']
# Word 'b'things'' after merging: [b'th', b'i', b'n', b'g', b's']
# Word 'b'something'' after merging: [b's', b'o', b'm', b'e', b'th', b'i', b'n', b'g']
# Word 'b'authoring'' after merging: [b'a', b'u', b'th', b'o', b'r', b'i', b'n', b'g']
# Word 'b'otherwise'' after merging: [b'o', b'th', b'e', b'r', b'w', b'i', b's', b'e']
# Word 'b'thousands'' after merging: [b'th', b'o', b'u', b's', b'a', b'n', b'd', b's']
# Word 'b'third'' after merging: [b'th', b'i', b'r', b'd']
# Word 'b'growth'' after merging: [b'g', b'r', b'o', b'w', b'th']
# Word 'b'together'' after merging: [b't', b'o', b'g', b'e', b'th', b'e', b'r']
# Word 'b'thin'' after merging: [b'th', b'i', b'n']
# Word 'b'northeast'' after merging: [b'n', b'o', b'r', b'th', b'e', b'a', b's', b't']
# Word 'b'south'' after merging: [b's', b'o', b'u', b'th']
# Word 'b'north'' after merging: [b'n', b'o', b'r', b'th']
# Word 'b'everything'' after merging: [b'e', b'v', b'e', b'r', b'y', b'th', b'i', b'n', b'g']
# Word 'b'Python'' after merging: [b'P', b'y', b'th', b'o', b'n']
# Word 'b'Guesthouses'' after merging: [b'G', b'u', b'e', b's', b'th', b'o', b'u', b's', b'e', b's']
# Word 'b'Carthaginians'' after merging: [b'C', b'a', b'r', b'th', b'a', b'g', b'i', b'n', b'i', b'a', b'n', b's']
# Word 'b'thriving'' after merging: [b'th', b'r', b'i', b'v', b'i', b'n', b'g']
# Word 'b'th'' after merging: [b'th']
# Word 'b'southern'' after merging: [b's', b'o', b'u', b'th', b'e', b'r', b'n']
# Word 'b'thousand'' after merging: [b'th', b'o', b'u', b's', b'a', b'n', b'd']
# Word 'b'Aparthotels'' after merging: [b'A', b'p', b'a', b'r', b'th', b'o', b't', b'e', b'l', b's']
# Word 'b'either'' after merging: [b'e', b'i', b'th', b'e', b'r']
# Word 'b'Another'' after merging: [b'A', b'n', b'o', b'th', b'e', b'r']
# Word 'b'thoroughly'' after merging: [b'th', b'o', b'r', b'o', b'u', b'g', b'h', b'l', b'y']
# Word 'b'author'' after merging: [b'a', b'u', b'th', b'o', b'r']
# Word 'b'others'' after merging: [b'o', b'th', b'e', b'r', b's']
# Word 'b'think'' after merging: [b'th', b'i', b'n', b'k']
# Word 'b'beneath'' after merging: [b'b', b'e', b'n', b'e', b'a', b'th']
# Word 'b'thrown'' after merging: [b'th', b'r', b'o', b'w', b'n']
# Word 'b'depths'' after merging: [b'd', b'e', b'p', b'th', b's']
# Word 'b'depth'' after merging: [b'd', b'e', b'p', b'th']
# Word 'b'width'' after merging: [b'w', b'i', b'd', b'th']
# Word 'b'although'' after merging: [b'a', b'l', b'th', b'o', b'u', b'g', b'h']
# Word 'b'themselves'' after merging: [b'th', b'e', b'm', b's', b'e', b'l', b'v', b'e', b's']
# Word 'b'Northern'' after merging: [b'N', b'o', b'r', b'th', b'e', b'r', b'n']
# Word 'b'health'' after merging: [b'h', b'e', b'a', b'l', b'th']
# Word 'b'northern'' after merging: [b'n', b'o', b'r', b'th', b'e', b'r', b'n']
# Word 'b'Width'' after merging: [b'W', b'i', b'd', b'th']
# Word 'b'Depth'' after merging: [b'D', b'e', b'p', b'th']
# Word 'b'month'' after merging: [b'm', b'o', b'n', b'th']
# Word 'b'Gareth'' after merging: [b'G', b'a', b'r', b'e', b'th']
# Word 'b'South'' after merging: [b'S', b'o', b'u', b'th']
# Word 'b'though'' after merging: [b'th', b'o', b'u', b'g', b'h']
# Word 'b'thinking'' after merging: [b'th', b'i', b'n', b'k', b'i', b'n', b'g']
# Word 'b'birth'' after merging: [b'b', b'i', b'r', b'th']
# Word 'b'death'' after merging: [b'd', b'e', b'a', b'th']
# Word 'b'parentheses'' after merging: [b'p', b'a', b'r', b'e', b'n', b'th', b'e', b's', b'e', b's']
# Word 'b'mother'' after merging: [b'm', b'o', b'th', b'e', b'r']
# Word 'b'brother'' after merging: [b'b', b'r', b'o', b'th', b'e', b'r']
# Word 'b'whether'' after merging: [b'w', b'h', b'e', b'th', b'e', b'r']
# Word 'b'thanks'' after merging: [b'th', b'a', b'n', b'k', b's']
# Word 'b'Lufthansa'' after merging: [b'L', b'u', b'f', b'th', b'a', b'n', b's', b'a']
# Word 'b'North'' after merging: [b'N', b'o', b'r', b'th']
# Word 'b'fathered'' after merging: [b'f', b'a', b'th', b'e', b'r', b'e', b'd']
# Word 'b'path'' after merging: [b'p', b'a', b'th']
# Word 'b'further'' after merging: [b'f', b'u', b'r', b'th', b'e', b'r']
# Word 'b'strengthen'' after merging: [b's', b't', b'r', b'e', b'n', b'g', b'th', b'e', b'n']
# Word 'b'themes'' after merging: [b'th', b'e', b'm', b'e', b's']
# Word 'b'authors'' after merging: [b'a', b'u', b'th', b'o', b'r', b's']
# Word 'b'theme'' after merging: [b'th', b'e', b'm', b'e']
# Word 'b'nothing'' after merging: [b'n', b'o', b'th', b'i', b'n', b'g']
# Word 'b'methodologies'' after merging: [b'm', b'e', b'th', b'o', b'd', b'o', b'l', b'o', b'g', b'i', b'e', b's']
# Word 'b'three'' after merging: [b'th', b'r', b'e', b'e']
# Word 'b'anything'' after merging: [b'a', b'n', b'y', b'th', b'i', b'n', b'g']
# Word 'b'breathe'' after merging: [b'b', b'r', b'e', b'a', b'th', b'e']
# Word 'b'thing'' after merging: [b'th', b'i', b'n', b'g']
# Word 'b'therefore'' after merging: [b'th', b'e', b'r', b'e', b'f', b'o', b'r', b'e']
# Word 'b'methods'' after merging: [b'm', b'e', b'th', b'o', b'd', b's']
# Word 'b'thoughout'' after merging: [b'th', b'o', b'u', b'g', b'h', b'o', b'u', b't']
# Word 'b'worth'' after merging: [b'w', b'o', b'r', b'th']
# Word 'b'forth'' after merging: [b'f', b'o', b'r', b'th']
# Word 'b'brethren'' after merging: [b'b', b'r', b'e', b'th', b'r', b'e', b'n']
# Word 'b'father'' after merging: [b'f', b'a', b'th', b'e', b'r']
# Word 'b'notwithstanding'' after merging: [b'n', b'o', b't', b'w', b'i', b'th', b's', b't', b'a', b'n', b'd', b'i', b'n', b'g']
# Word 'b'hath'' after merging: [b'h', b'a', b'th']
# Word 'b'passeth'' after merging: [b'p', b'a', b's', b's', b'e', b'th']
# Word 'b'earth'' after merging: [b'e', b'a', b'r', b'th']
# Word 'b'authority'' after merging: [b'a', b'u', b'th', b'o', b'r', b'i', b't', b'y']
# Word 'b'truth'' after merging: [b't', b'r', b'u', b'th']
# Word 'b'mouth'' after merging: [b'm', b'o', b'u', b'th']
# Word 'b'thou'' after merging: [b'th', b'o', b'u']
# Word 'b'nevertheless'' after merging: [b'n', b'e', b'v', b'e', b'r', b'th', b'e', b'l', b'e', b's', b's']
# Word 'b'faithful'' after merging: [b'f', b'a', b'i', b'th', b'f', b'u', b'l']
# Word 'b'thy'' after merging: [b'th', b'y']
# Word 'b'cometh'' after merging: [b'c', b'o', b'm', b'e', b'th']
# Word 'b'Nevertheless'' after merging: [b'N', b'e', b'v', b'e', b'r', b'th', b'e', b'l', b'e', b's', b's']
# Word 'b'thine'' after merging: [b'th', b'i', b'n', b'e']
# Word 'b'youth'' after merging: [b'y', b'o', b'u', b'th']
# Word 'b'offereth'' after merging: [b'o', b'f', b'f', b'e', b'r', b'e', b'th']
# Word 'b'neither'' after merging: [b'n', b'e', b'i', b'th', b'e', b'r']
# Word 'b'lengthened'' after merging: [b'l', b'e', b'n', b'g', b'th', b'e', b'n', b'e', b'd']
# Word 'b'knoweth'' after merging: [b'k', b'n', b'o', b'w', b'e', b'th']
# Word 'b'seeketh'' after merging: [b's', b'e', b'e', b'k', b'e', b'th']
# Word 'b'therein'' after merging: [b'th', b'e', b'r', b'e', b'i', b'n']
# Word 'b'giveth'' after merging: [b'g', b'i', b'v', b'e', b'th']
# Word 'b'thus'' after merging: [b'th', b'u', b's']
# Word 'b'seventh'' after merging: [b's', b'e', b'v', b'e', b'n', b'th']
# Word 'b'breathed'' after merging: [b'b', b'r', b'e', b'a', b'th', b'e', b'd']
# Word 'b'breath'' after merging: [b'b', b'r', b'e', b'a', b'th']
# Word 'b'thence'' after merging: [b'th', b'e', b'n', b'c', b'e']
# Word 'b'thereof'' after merging: [b'th', b'e', b'r', b'e', b'o', b'f']
# Word 'b'faith'' after merging: [b'f', b'a', b'i', b'th']
# Word 'b'throughout'' after merging: [b'th', b'r', b'o', b'u', b'g', b'h', b'o', b'u', b't']
# Word 'b'thereby'' after merging: [b'th', b'e', b'r', b'e', b'b', b'y']
# Word 'b'Father'' after merging: [b'F', b'a', b'th', b'e', b'r']
# Word 'b'priesthood'' after merging: [b'p', b'r', b'i', b'e', b's', b'th', b'o', b'o', b'd']
# Word 'b'tithes'' after merging: [b't', b'i', b'th', b'e', b's']
# Word 'b'tenth'' after merging: [b't', b'e', b'n', b'th']
# Word 'b'doth'' after merging: [b'd', b'o', b'th']
# Word 'b'fathers'' after merging: [b'f', b'a', b'th', b'e', b'r', b's']
# Word 'b'wrath'' after merging: [b'w', b'r', b'a', b'th']
# Word 'b'Smith'' after merging: [b'S', b'm', b'i', b'th']
# Word 'b'teeth'' after merging: [b't', b'e', b'e', b'th']
# Word 'b'altogether'' after merging: [b'a', b'l', b't', b'o', b'g', b'e', b'th', b'e', b'r']
# Word 'b'withdrew'' after merging: [b'w', b'i', b'th', b'd', b'r', b'e', b'w']
# Word 'b'thee'' after merging: [b'th', b'e', b'e']
# Word 'b'thyself'' after merging: [b'th', b'y', b's', b'e', b'l', b'f']
# Word 'b'doeth'' after merging: [b'd', b'o', b'e', b'th']
# Word 'b'draweth'' after merging: [b'd', b'r', b'a', b'w', b'e', b'th']
# Word 'b'rideth'' after merging: [b'r', b'i', b'd', b'e', b'th']
# Word 'b'behooveth'' after merging: [b'b', b'e', b'h', b'o', b'o', b'v', b'e', b'th']
# Word 'b'clothing'' after merging: [b'c', b'l', b'o', b'th', b'i', b'n', b'g']

# %%
from cs336_basics.bpe.tokenization import train_bpe_tokenizer


vocab, merges = train_bpe_tokenizer(
    splits,
    word_counts,
    vocab_size=500,
)
print(f"Number of merges: {len(merges)}")
print(f"Vocabulary size after training: {len(vocab)}")
# Out:
# Number of merges: 500
# Vocabulary size after training: 500

# %%
vocabs_without_specials = [
    word for word in vocab.values() if word != b"<|endoftext|>"
]
for word_bytes in vocabs_without_specials:
    assert b"<|" not in word_bytes

# %% [markdown]
# # E2E training of a BPE tokenizer

# %%
from cs336_basics.bpe import train_bpe

# %%
vocab, merges = train_bpe(
    input_path=Path('.').parent / "tests/fixtures/corpus.en",
    vocab_size=500,
    special_tokens=["<|endoftext|>"],
)

# %%
from tests.common import FIXTURES_PATH, gpt2_bytes_to_unicode
import json

# %%
input_path = FIXTURES_PATH / "corpus.en"
vocab, merges = train_bpe(
    input_path=input_path,
    vocab_size=500,
    special_tokens=["<|endoftext|>"],
)

# %%
# Path to the reference tokenizer vocab and merges
reference_vocab_path = FIXTURES_PATH / "train-bpe-reference-vocab.json"
reference_merges_path = FIXTURES_PATH / "train-bpe-reference-merges.txt"

# Compare the learned merges to the expected output merges
gpt2_byte_decoder = {v: k for k, v in gpt2_bytes_to_unicode().items()}


with open(reference_merges_path) as f:
    gpt2_reference_merges = [tuple(line.rstrip().split(" ")) for line in f]
    reference_merges = [
        (
            bytes([gpt2_byte_decoder[token] for token in merge_token_1]),
            bytes([gpt2_byte_decoder[token] for token in merge_token_2]),
        )
        for merge_token_1, merge_token_2 in gpt2_reference_merges
    ]

# %%
assert merges == reference_merges

# %%
# Compare the vocab to the expected output vocab
with open(reference_vocab_path) as f:
    gpt2_reference_vocab = json.load(f)
    reference_vocab = {
        gpt2_vocab_index: bytes(
            [gpt2_byte_decoder[token] for token in gpt2_vocab_item]
        )
        for gpt2_vocab_item, gpt2_vocab_index in gpt2_reference_vocab.items()
    }

# %%
[word for word in vocab.values() if word.decode("utf-8") == "<|endoftext|>"]
# Out:
# [b'<|endoftext|>']
